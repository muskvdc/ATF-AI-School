# %% [markdown]
# # Week 1.4: Prompt Engineering for Digital Twins
#
# ## Learning Objectives
# - Master different prompting techniques
# - Understand zero-shot, few-shot, and chain-of-thought
# - Apply prompting to digital twin interactions
#
# ## Key Insight
# > 'Moving from Chat to System Instructions'

# %%
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Dict

print('✅ Ready for prompting exercises!')
# Out:
# ✅ Ready for prompting exercises!

# %% [markdown]
# ## Part 1: Prompting Fundamentals
#
# ### 1.1 Zero-Shot Prompting

# %%
# Example prompts for digital twin
zero_shot_examples = [
    {
        'task': 'activity_prediction',
        'prompt': 'Predict the next activity: I just finished work, had dinner, and now...',
        'expected': 'leisure/relaxation activity'
    },
    {
        'task': 'preference_extraction',
        'prompt': 'Extract preferences from: I love outdoor activities but hate crowded places',
        'expected': {'likes': ['outdoor', 'quiet'], 'dislikes': ['crowds']}
    }
]

print('Zero-Shot Examples:')
for ex in zero_shot_examples:
    print(f"\nTask: {ex['task']}")
    print(f"Prompt: {ex['prompt']}")
    print(f"Expected: {ex['expected']}")
# Out:
# Zero-Shot Examples:
#
# Task: activity_prediction
# Prompt: Predict the next activity: I just finished work, had dinner, and now...
# Expected: leisure/relaxation activity
#
# Task: preference_extraction
# Prompt: Extract preferences from: I love outdoor activities but hate crowded places
# Expected: {'likes': ['outdoor', 'quiet'], 'dislikes': ['crowds']}

# %% [markdown]
# ### 🎯 Exercise 1.1 (Easy): Create Your Prompts
#
# **Task**: Design prompts for your digital twin use case.

# %%
# YOUR CODE HERE
# !pip install -q groq

import os
from groq import Groq
import os, json
#IMPORTANT: Set your real API key securely.
#Option 1 (recommended): Set this in your environment before running the notebook:
#   %env GROQ_API_KEY=gsk_.....

#Option 2 (Only for quick local testing): Paste it here (NOT in shared notebooks)
os.environ["GROQ_API_KEY"] = "gsk_....."

client=Groq(
    api_key=os.environ.get("GROQ_API_KEY")
)

def llm(prompt: str) -> str:
  """Simple helper for single-turn prompts."""
  chat_completion = client.chat.completions.create(
      model="openai/gpt-oss-120b",
      messages=[
          {"role": "user", "content": prompt}
      ]
  )
  return chat_completion.choices[0].message.content

print("Connected. Ready.")
# Out:
# Connected. Ready.

# %%
#Zero-shot Prompting
# Zero-shot: describe the task only
# No examples, no format instructions
# Model infers the answer from training

prompt = '''
Predict the next activity.
I'm busy studying AI. I'm tired.
What do you recommend?
'''
response = llm(prompt)
print(response)
# Out:
# Here are a few ideas for what you could do next — designed to give you a quick energy boost, clear your mind, and help you get back to studying AI feeling refreshed.
#
# ---
#
# ## 1️⃣ Take a **Power‑Nap** (10‑20 min)
# - **Why it works:** A short nap restores alertness, improves memory consolidation, and reduces the feeling of fatigue without making you groggy.
# - **How to do it:**
#   1. Set a timer for 10–20 minutes.
#   2. Find a dark, quiet spot (a bedroom, couch, or even a “nap pod” if you have one).
#   3. Turn off notifications and close your eyes.
#   4. When the timer goes off, sit up slowly and stretch.
#
# ---
#
# ## 2️⃣ Do a **Micro‑Movement Break** (5‑10 min)
# - **Why it works:** Light movement increases blood flow to the brain, raises dopamine levels, and combats the “couch‑stuck” slump that comes from prolonged sitting.
# - **Quick options:**
#   - 30 seconds of jumping jacks → 30 seconds of marching in place → repeat 3×.
#   - 10 body‑weight squats → 10 push‑ups (or wall push‑ups) → 10 lunges (each leg).
#   - A brisk 2‑minute walk around the room or outside, focusing on deep breathing.
#
# ---
#
# ## 3️⃣ **Mindful Reset** (3‑7 min)
# - **Why it works:** A short mindfulness or breathing exercise can lower cortisol, improve focus, and give you a mental “reset button.”
# - **Simple script:**
#   1. Sit comfortably, eyes closed.
#   2. Inhale for a count of 4, hold 2, exhale for 6.
#   3. Repeat for 5–7 cycles, letting thoughts drift by without judgment.
#   4. Open your eyes, notice any shift in how you feel.
#
# ---
#
# ## 4️⃣ **Refresh with a Light Snack + Hydration**
# - **Why it works:** Low blood‑glucose can masquerade as fatigue. A balanced snack supplies steady energy.
# - **Ideas:**
#   - Greek yogurt + a handful of berries.
#   - A slice of whole‑grain toast with almond butter.
#   - A small handful of mixed nuts + a piece of fruit.
#   - Pair with water, herbal tea, or a modest cup of coffee (if you tolerate caffeine well).
#
# ---
#
# ## 5️⃣ **Change the Study Modality**
# If you feel “tired of the screen,” switch the way you engage with AI concepts for a few minutes:
# - **Read a short, non‑technical article** about AI ethics, history, or a cool application (e.g., AI in art or medicine).
# - **Watch a 3‑minute explainer video** (Khan Academy, 3Blue1Brown, or a concise YouTube tutorial).
# - **Sketch a concept map** of what you’ve learned so far—drawing forces you to recall actively while giving your eyes a break from text.
#
# ---
#
# ### Putting It Together – A Sample 20‑Minute Routine
#
# | Time | Activity | Goal |
# |------|----------|------|
# | 0‑2 min | Stand, stretch arms overhead, roll shoulders | Release tension |
# | 2‑7 min | Power‑nap (set a 5‑minute alarm) | Quick mental reset |
# | 7‑12 min | Hydrate & eat a light snack | Stabilize blood‑sugar |
# | 12‑15 min | 3‑minute mindful breathing | Reduce stress |
# | 15‑20 min | Walk around the room or outside while listening to a favorite song | Boost circulation & mood |
#
# After this mini‑reset, you should feel more alert and ready to dive back into your AI material.
#
# ---
#
# ## 🎯 How to Choose the Best Option for You
#
# | Situation | Best pick |
# |-----------|-----------|
# | **Very drowsy / eyes heavy** | Power‑nap (10‑20 min) |
# | **Need to stay awake, but can’t sleep** | Micro‑movement break + hydration |
# | **Feeling mentally cluttered** | Mindful reset |
# | **Low on energy, stomach growling** | Snack + water |
# | **Screen fatigue** | Switch modality (read, watch, sketch) |
#
# You can even combine two: a 5‑minute stretch + a 5‑minute snack, then a 5‑minute mindfulness session, and finally a quick 5‑minute walk. The key is **intentional, short breaks**—they’re scientifically proven to improve retention and creativity when you return to study.
#
# ---
#
# ### Quick Checklist (Copy‑Paste)
#
# ```
# [ ] Set timer for 10‑20 min nap OR 5‑min stretch
# [ ] Drink 250 ml water
# [ ] Grab snack (protein + fruit)
# [ ] 5‑minute breathing (4‑2‑6 count)
# [ ] 5‑minute walk or light cardio
# [ ] Return to AI study, refreshed!
# ```
#
# ---
#
# **Bottom line:** Give your brain and body a brief, purposeful pause. Even a 10‑minute “reset” can dramatically lift your focus, reduce the feeling of exhaustion, and make the next study session more productive. 🌟
#
# Feel free to let me know which option you try, or if you want a customized schedule based on your typical study blocks!
